# %%
import sqlite3
import pandas as pd

# %% [markdown]
# # Functions

# %%
def fetch_full_table(table_name):
    """Function for return a full table from the database
    just passing the table_name
    args:
    table_name, str
    return:
    list   
    """
    cursor.execute(f"SELECT * FROM {table_name} LIMIT 10;")
    return cursor.fetchall()

# %%
def fetch_query(cursor, query):
    cursor.execute(query)
    return cursor.fetchall()

# %%
def pandas_query(connection, query):
    return pd.read_sql_query(query, connection)

# %% [markdown]
# # EDA

# %%
# data source: https://www.kaggle.com/datasets/hugomathien/soccer

# %%
# Create a SQL connection to our SQLite database
con = sqlite3.connect("datasets/football/soccer/database.sqlite")
cursor = con.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table' LIMIT 10;")
table_names = cursor.fetchall()

# %%
table_names
# Out:
# [('sqlite_sequence',),
#  ('Player_Attributes',),
#  ('Player',),
#  ('Match',),
#  ('League',),
#  ('Country',),
#  ('Team',),
#  ('Team_Attributes',)]

# %%
pandas_query(con, "SELECT * FROM Match")
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 0          1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1          2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2          3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3          4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4          5           1          1  2008/2009      1  2008-08-16 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 25974  25975       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25975  25976       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25976  25977       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25977  25978       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25978  25979       24558      24558  2015/2016      9  2015-09-23 00:00:00
#
# ...
